# %%
# !git clone https://github.com/shu4dev/ECE491_Assignment2.git
# %cd ECE491_Assignment2
# !git pull
# !git checkout main
# !pip install -e ./cs336-basics/ -e ./cs336-data/'[test]'
# Out:
# fatal: destination path 'ECE491_Assignment2' already exists and is not an empty directory.
# /content/ECE491_Assignment2
# Already up to date.
# Already on 'main'
# Your branch is up to date with 'origin/main'.
# Obtaining file:///content/ECE491_Assignment2/cs336-basics
#   Preparing metadata (setup.py) ... done
# Obtaining file:///content/ECE491_Assignment2/cs336-data
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 4.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached pybind11-2.13.6-py3-none-any.whl.metadata (9.5 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 57.8 MB/s eta 0:00:00
# ...

# %%
# !pytest -v
# Out:
# ======================================= test session starts ========================================
# platform linux -- Python 3.11.11, pytest-8.3.5, pluggy-1.5.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/ECE491_Assignment2
# plugins: langsmith-0.3.18, anyio-4.9.0, typeguard-4.4.2
# collected 0 items / 6 errors
#
# ============================================== ERRORS ==============================================
# _____________________ ERROR collecting cs336-data/tests/test_deduplication.py ______________________
# ImportError while importing test module '/content/ECE491_Assignment2/cs336-data/tests/test_deduplication.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# /usr/lib/python3.11/importlib/__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# cs336-data/tests/test_deduplication.py:6: in <module>
# ...
